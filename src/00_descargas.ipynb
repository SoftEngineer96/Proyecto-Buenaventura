# %% [markdown]
# # 00. Fuentes y descarga
#
# Comprueba los archivos DANE 2012-2026 y permite descargarlos cuando no estén disponibles. Los ZIP se guardan en `data/raw/dane`.

# %%
from pathlib import Path
import os
import sys

try:
    from google.colab import drive
    drive.mount('/content/drive')
    PROJECT_ROOT = Path('/content/drive/MyDrive/Proyecto_Buenaventura_Final')
except ImportError:
    PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'src' else Path.cwd().resolve()

os.environ['PROYECTO_BUENAVENTURA_ROOT'] = str(PROJECT_ROOT)
os.chdir(PROJECT_ROOT / 'src')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))
print('Proyecto:', PROJECT_ROOT)
# Out:
# Proyecto: C:\Users\juanc\Desktop\Proyecto_Buenaventura_Final

# %%
from pipeline import FILES, RAW_DANE, download_sources, valid_zip

estado = {name: valid_zip(RAW_DANE / name) for name in FILES}
print(f"Archivos disponibles: {sum(estado.values())}/{len(estado)}")
estado
# Out:
# Archivos disponibles: 18/18
# {'Impo_2012.zip': True,
#  'Impo_2013.zip': True,
#  'Impo_2014.zip': True,
#  'Impo_2015.zip': True,
#  'Impo_2016.zip': True,
#  'Impo_2017.zip': True,
#  'Impo_2018.zip': True,
#  'Impo_2019.zip': True,
#  'Impo_2020.zip': True,
#  'Impo_2021_1.zip': True,
#  'Impo_2021_2.zip': True,
#  'Impo_2022_1.zip': True,
#  'Impo_2022_2.zip': True,
#  'Impo_2023.zip': True,
#  'Impo_2024.zip': True,
#  'Impo_2025_1.zip': True,
#  'Impo_2025_2.zip': True,
#  'Impo_2026.zip': True}

# %%
DESCARGAR_FALTANTES = False
if DESCARGAR_FALTANTES:
    download_sources()
else:
    print('Descarga omitida. Cambie DESCARGAR_FALTANTES a True si faltan archivos.')
# Out:
# Descarga omitida. Cambie DESCARGAR_FALTANTES a True si faltan archivos.
